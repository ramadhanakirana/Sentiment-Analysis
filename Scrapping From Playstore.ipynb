# %%
#Install package
import pip
pip.main(['install','google-play-scraper'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# 0

# %%
from google_play_scraper import app, Sort, reviews
import pandas as pd
import numpy as np

# %%
#Ambil beberapa review
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'app.bpjs.mobile',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 12000,
    filter_score_with = None
)

# %%
df_jkn = pd.DataFrame(np.array(result), columns = ['review'])
df_jkn = df_jkn.join(pd.DataFrame(df_jkn.pop('review').tolist()))
df_jkn.head()
# Out:
#                                reviewId             userName  \
# 0  f53e175f-1d0f-453b-be72-a03825035b06  Muklis Hidayatullah
# 1  09e32292-48c4-41ae-bdb5-00d7ed6e90e8       Ganjar Purnama
# 2  e035be69-6e1c-4fec-a451-6f5aed5a212f   Muhamad Burhanudin
# 3  2b6a98b4-fde8-4d25-a9e2-437f5da36a73       callista putri
# 4  324cfb4d-8c6a-4e1e-b37c-0bd25df7e7de     agus wahyudiyono
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                            content  score  thumbsUpCount  \
# 0                           Sangat membantu banget      5              0
# 1                                   Tingkatkan !!!      5              0
# ...

# %%
df_jkn = pd.DataFrame(np.array(result), columns = ['review'])
df_jkn = df_jkn.join(pd.DataFrame(df_jkn.pop('review').tolist()))
df_jkn.head()
# Out:
#                                reviewId             userName  \
# 0  f53e175f-1d0f-453b-be72-a03825035b06  Muklis Hidayatullah
# 1  09e32292-48c4-41ae-bdb5-00d7ed6e90e8       Ganjar Purnama
# 2  e035be69-6e1c-4fec-a451-6f5aed5a212f   Muhamad Burhanudin
# 3  2b6a98b4-fde8-4d25-a9e2-437f5da36a73       callista putri
# 4  324cfb4d-8c6a-4e1e-b37c-0bd25df7e7de     agus wahyudiyono
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                            content  score  thumbsUpCount  \
# 0                           Sangat membantu banget      5              0
# 1                                   Tingkatkan !!!      5              0
# ...

# %%
df_jkn_fix = df_jkn[['userName', 'score', 'at', 'content']]

# %%
df_jkn_fix.to_csv("coba 2 scrapped jkn.csv", index = False)
